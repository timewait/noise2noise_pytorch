# %%
from model import get_model

# %%
m = get_model("unet")
for k, v in m.named_parameters():
    if v.requires_grad:
        print(f"{k}: {v.shape}")
    else:
        print(f"{k} (not trainable): {v.shape}")
# Out:
# encoder_blocks.0.conv.0.weight: torch.Size([64, 3, 3, 3])
# encoder_blocks.0.conv.0.bias: torch.Size([64])
# encoder_blocks.0.conv.2.weight: torch.Size([64, 64, 3, 3])
# encoder_blocks.0.conv.2.bias: torch.Size([64])
# encoder_blocks.1.conv.0.weight: torch.Size([128, 64, 3, 3])
# encoder_blocks.1.conv.0.bias: torch.Size([128])
# encoder_blocks.1.conv.2.weight: torch.Size([128, 128, 3, 3])
# encoder_blocks.1.conv.2.bias: torch.Size([128])
# encoder_blocks.2.conv.0.weight: torch.Size([256, 128, 3, 3])
# encoder_blocks.2.conv.0.bias: torch.Size([256])
# encoder_blocks.2.conv.2.weight: torch.Size([256, 256, 3, 3])
# encoder_blocks.2.conv.2.bias: torch.Size([256])
# encoder_blocks.3.conv.0.weight: torch.Size([512, 256, 3, 3])
# encoder_blocks.3.conv.0.bias: torch.Size([512])
# encoder_blocks.3.conv.2.weight: torch.Size([512, 512, 3, 3])
# encoder_blocks.3.conv.2.bias: torch.Size([512])
# encoder_blocks.4.conv.0.weight: torch.Size([1024, 512, 3, 3])
# ...
